# %% [markdown]
# # Gemma 3-4B, 1-2B LoRA Fine-Tuning

# %% [markdown]
# ## 라이브러리 설치

# %%
try:
    inColab = True
except ImportError:
    inColab = False

# %%
if inColab == True:
    # !pip install -U pandas==2.2.2 numpy==2.0.2 scipy==1.14.1 accelerate==1.6.0 peft==0.15.2 bitsandbytes==0.45.5 transformers==4.51.3 trl==0.16.1 datasets==3.5.0 tensorboard==2.19.0
# Out:
# Collecting pandas==2.2.2
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting numpy==2.0.2
#   Using cached numpy-2.0.2-cp311-cp311-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: scipy==1.14.1 in c:\users\hp\.llmall\lib\site-packages (1.14.1)
# Requirement already satisfied: accelerate==1.6.0 in c:\users\hp\.llmall\lib\site-packages (1.6.0)
# Requirement already satisfied: peft==0.15.2 in c:\users\hp\.llmall\lib\site-packages (0.15.2)
# Requirement already satisfied: bitsandbytes==0.45.5 in c:\users\hp\.llmall\lib\site-packages (0.45.5)
# Requirement already satisfied: transformers==4.51.3 in c:\users\hp\.llmall\lib\site-packages (4.51.3)
# Requirement already satisfied: trl==0.16.1 in c:\users\hp\.llmall\lib\site-packages (0.16.1)
# Requirement already satisfied: datasets==3.5.0 in c:\users\hp\.llmall\lib\site-packages (3.5.0)
# Requirement already satisfied: tensorboard==2.19.0 in c:\users\hp\.llmall\lib\site-packages (2.19.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\.llmall\lib\site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\.llmall\lib\site-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\.llmall\lib\site-packages (from pandas==2.2.2) (2025.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\.llmall\lib\site-packages (from accelerate==1.6.0) (25.0)
# Requirement already satisfied: psutil in c:\users\hp\.llmall\lib\site-packages (from accelerate==1.6.0) (7.1.3)
# Requirement already satisfied: pyyaml in c:\users\hp\.llmall\lib\site-packages (from accelerate==1.6.0) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in c:\users\hp\.llmall\lib\site-packages (from accelerate==1.6.0) (2.7.0+cu118)
# Requirement already satisfied: huggingface-hub>=0.21.0 in c:\users\hp\.llmall\lib\site-packages (from accelerate==1.6.0) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\hp\.llmall\lib\site-packages (from accelerate==1.6.0) (0.7.0)
# Requirement already satisfied: tqdm in c:\users\hp\.llmall\lib\site-packages (from peft==0.15.2) (4.67.1)
# Requirement already satisfied: filelock in c:\users\hp\.llmall\lib\site-packages (from transformers==4.51.3) (3.20.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hp\.llmall\lib\site-packages (from transformers==4.51.3) (2025.11.3)
# Requirement already satisfied: requests in c:\users\hp\.llmall\lib\site-packages (from transformers==4.51.3) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\hp\.llmall\lib\site-packages (from transformers==4.51.3) (0.21.4)
# Requirement already satisfied: rich in c:\users\hp\.llmall\lib\site-packages (from trl==0.16.1) (14.2.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\hp\.llmall\lib\site-packages (from datasets==3.5.0) (22.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\hp\.llmall\lib\site-packages (from datasets==3.5.0) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\hp\.llmall\lib\site-packages (from datasets==3.5.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\hp\.llmall\lib\site-packages (from datasets==3.5.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in c:\users\hp\.llmall\lib\site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets==3.5.0) (2024.12.0)
# Requirement already satisfied: aiohttp in c:\users\hp\.llmall\lib\site-packages (from datasets==3.5.0) (3.13.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\hp\.llmall\lib\site-packages (from tensorboard==2.19.0) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\hp\.llmall\lib\site-packages (from tensorboard==2.19.0) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hp\.llmall\lib\site-packages (from tensorboard==2.19.0) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\hp\.llmall\lib\site-packages (from tensorboard==2.19.0) (6.33.2)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\hp\.llmall\lib\site-packages (from tensorboard==2.19.0) (65.5.0)
# Requirement already satisfied: six>1.9 in c:\users\hp\.llmall\lib\site-packages (from tensorboard==2.19.0) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hp\.llmall\lib\site-packages (from tensorboard==2.19.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hp\.llmall\lib\site-packages (from tensorboard==2.19.0) (3.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\hp\.llmall\lib\site-packages (from aiohttp->datasets==3.5.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\hp\.llmall\lib\site-packages (from aiohttp->datasets==3.5.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp\.llmall\lib\site-packages (from aiohttp->datasets==3.5.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hp\.llmall\lib\site-packages (from aiohttp->datasets==3.5.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hp\.llmall\lib\site-packages (from aiohttp->datasets==3.5.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\hp\.llmall\lib\site-packages (from aiohttp->datasets==3.5.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\hp\.llmall\lib\site-packages (from aiohttp->datasets==3.5.0) (1.22.0)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\hp\.llmall\lib\site-packages (from grpcio>=1.48.2->tensorboard==2.19.0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\.llmall\lib\site-packages (from requests->transformers==4.51.3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\.llmall\lib\site-packages (from requests->transformers==4.51.3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\.llmall\lib\site-packages (from requests->transformers==4.51.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\.llmall\lib\site-packages (from requests->transformers==4.51.3) (2025.11.12)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\hp\.llmall\lib\site-packages (from torch>=2.0.0->accelerate==1.6.0) (1.14.0)
# Requirement already satisfied: networkx in c:\users\hp\.llmall\lib\site-packages (from torch>=2.0.0->accelerate==1.6.0) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\hp\.llmall\lib\site-packages (from torch>=2.0.0->accelerate==1.6.0) (3.1.6)
# Requirement already satisfied: colorama in c:\users\hp\.llmall\lib\site-packages (from tqdm->peft==0.15.2) (0.4.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\hp\.llmall\lib\site-packages (from werkzeug>=1.0.1->tensorboard==2.19.0) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\.llmall\lib\site-packages (from rich->trl==0.16.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\.llmall\lib\site-packages (from rich->trl==0.16.1) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\.llmall\lib\site-packages (from markdown-it-py>=2.2.0->rich->trl==0.16.1) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\.llmall\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate==1.6.0) (1.3.0)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Using cached numpy-2.0.2-cp311-cp311-win_amd64.whl (15.9 MB)
# Installing collected packages: numpy, pandas
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.3.1
#     Uninstalling pandas-2.3.1:
#       Successfully uninstalled pandas-2.3.1
# Successfully installed numpy-2.0.2 pandas-2.2.2
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 라이브러리 선언

# %%
import os
import random
import numpy as np
import torch
from datasets import load_dataset

from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    set_seed,
)

from peft import LoraConfig, PeftModel
from trl import SFTTrainer, SFTConfig
from datetime import datetime

#  수정 포인트: 재현성(Seed 고정)
SEED = 42
set_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu")
# Out:
# GPU: NVIDIA RTX A5000

# %%
import huggingface_hub
# HuggingFace 로그인 (토큰 입력 필요할 수 있음)
huggingface_hub.login("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")

# %% [markdown]
# ## 1. 모델 및 데이터셋 설정

# %%
# base_model = "google/gemma-2b-it"
base_model = "google/gemma-3-4b-it"
# base_model = "familicare/elysium_general"
dataset_name = "familicare/health_general_knowledge"

# 데이터 로드
ds = load_dataset(dataset_name, split="train")

# 비율로 분할 (80% Train, 20% Eval)
# 데이터가 늘어나도 자동으로 비율이 유지됩니다.
ds = ds.train_test_split(test_size=0.2, seed=SEED)
train_ds = ds["train"]
eval_ds  = ds["test"]

print(f"Total: {len(ds['train']) + len(ds['test'])}")
print(f"Train size: {len(train_ds)} (80%)")
print(f"Eval  size: {len(eval_ds)} (20%)")
# Out:
# Total: 15360
# Train size: 12288 (80%)
# Eval  size: 3072 (20%)

# %%
# train_ds_filtered = train_ds.filter(lambda x: x["input"] == "내과")
# train_ds_filtered = train_ds_filtered.select(range(min(100, len(train_ds_filtered))))

# %%
train_ds = ds["train"]

# %% [markdown]
# ## 2. 토크나이저 설정 및 채팅 템플릿 적용

# %%
tokenizer = AutoTokenizer.from_pretrained(base_model, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token

# %%
def to_chat_text(example):
    instruction = example["instruction"].strip()
    user_input  = example["input"].strip()
    output      = example["output"].strip()

    user_msg = (
        f"{instruction}\n\n[입력]\n{user_input}" if instruction and user_input
        else instruction or user_input
    )

    messages = [
        {"role": "user", "content": user_msg},
        {"role": "assistant", "content": output},
    ]

    try:
        example["text"] = tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=False
        )
    except Exception:
        example["text"] = (
            "<start_of_turn>user\n"
            f"{user_msg}\n"
            "<end_of_turn>\n"
            "<start_of_turn>model\n"
            f"{output}\n"
            "<end_of_turn>"
        )

    return example

# %%
# def to_chat_text(example):
#     #example =train_ds[0]
#     """
#     ★수정 포인트: 모델이 원래 이해하도록 설계된 대화 포맷을 토크나이저가 알아서 생성
#     - tokenizer.apply_chat_template 사용 (모델 고유 포맷 준수)
#     - instruction/input이 비어있을 경우에 대한 로직 추가
#     """
#     instruction = (example.get("instruction") or "").strip()
#     user_input  = (example.get("input") or "").strip()
#     output      = (example.get("output") or "").strip()

#     # User 메시지 구성
#     if instruction and user_input:
#         user_msg = f"{instruction}\n\n[입력]\n{user_input}"
#     elif instruction:
#         user_msg = instruction
#     else:
#         user_msg = user_input

#     messages = [
#         {"role": "user", "content": user_msg},
#         {"role": "assistant", "content": output},
#     ]

#     # apply_chat_template 우선 시도
#     try:
#         text = tokenizer.apply_chat_template(
#             messages,
#             tokenize=False,
#             add_generation_prompt=False
#         )
#         example["text"] = text
#     except Exception:
#         # Fallback: 수동 포맷 (구분자 명확히)
#         example["text"] = (
#             "<start_of_turn>user\n"
#             f"{user_msg}\n"
#             "<end_of_turn>\n"
#             "<start_of_turn>model\n"
#             f"{output}\n"
#             "<end_of_turn>"
#         )
#     return example

# %%
train_ds = train_ds.map(
    to_chat_text,
    remove_columns=["instruction", "input", "output"]
)

eval_ds = eval_ds.map(
    to_chat_text,
    remove_columns=["instruction", "input", "output"]
)


# 변환된 데이터 확인
print("Sample Text:")
print(train_ds[0]["text"][:500])
# Out:
# Sample Text:
# <bos><start_of_turn>user
# 23세 여자가 3개월 전부터 기침을 한다며 내원했다. 기침은 밤에 누워 자려고 할 때 심해진다고 한다. 1년 전에도 같은 시기에 기침이 3개월 동안 지속되다가 저절로 호전된 병력이 있다. 콧물이나 인후부 불편감은 없으며, 비흡연자이고 복용 중인 약물도 없다. 신체검사에서 혈압 120/80mmHg, 맥박 78회/분, 호흡 18회/분, 체온 36.5°C로 측정되었다. 청진상 호흡음은 정상이었고, 가슴 X선 사진과 코곁굴 X선 사진에서도 이상 소견이 없었다. 폐기능검사 결과는 다음과 같다.
# - 강제 폐활량(FVC): 정상 예측치의 91%
# - 1초간 강제날숨유량(FEV1): 정상 예측치의 85%
# - 1초간 강제날숨유량/강제폐활량(FEV1/FVC): 75%
#
# 이 환자에서 다음으로 시행해야 할 검사는 무엇인가?
# 1) 기관지내시경
# 2) 기관지 확장제 반응 검사
# 3) 가슴 컴퓨터단층촬영(CT)
# 4) 메타콜린 기관지유발검사

# %%
# train_ds = train_ds.filter(lambda x: x["input"] == "내과")
# train_ds = train_ds.select(range(100))
# eval_ds=eval_ds.select(range(20))

# %%
train_ds[0]
# Out:
# {'text': '<bos><start_of_turn>user\n23세 여자가 3개월 전부터 기침을 한다며 내원했다. 기침은 밤에 누워 자려고 할 때 심해진다고 한다. 1년 전에도 같은 시기에 기침이 3개월 동안 지속되다가 저절로 호전된 병력이 있다. 콧물이나 인후부 불편감은 없으며, 비흡연자이고 복용 중인 약물도 없다. 신체검사에서 혈압 120/80mmHg, 맥박 78회/분, 호흡 18회/분, 체온 36.5°C로 측정되었다. 청진상 호흡음은 정상이었고, 가슴 X선 사진과 코곁굴 X선 사진에서도 이상 소견이 없었다. 폐기능검사 결과는 다음과 같다.  \n- 강제 폐활량(FVC): 정상 예측치의 91%  \n- 1초간 강제날숨유량(FEV1): 정상 예측치의 85%  \n- 1초간 강제날숨유량/강제폐활량(FEV1/FVC): 75%  \n\n이 환자에서 다음으로 시행해야 할 검사는 무엇인가?  \n1) 기관지내시경  \n2) 기관지 확장제 반응 검사  \n3) 가슴 컴퓨터단층촬영(CT) \n4) 메타콜린 기관지유발검사  \n5) 폐 확산능 검사\n\n[입력]\n내과<end_of_turn>\n<start_of_turn>model\n4) 메타콜린 기관지유발검사<end_of_turn>\n'}

# %% [markdown]
# ## 3. 환경 및 최적화 설정 (4-bit 양자화0

# %%
# 현재 사용 중인 GPU의 주요 아키텍처 버전을 반환 8버전 이상 시 bfloat16 활용
# NVIDIA Ampere 아키텍처 이상 시에만 처리
if torch.cuda.get_device_capability()[0] >= 8:
    # 고속 attention 메커니즘을 구현하는 라이브러리
    attn_implementation = "flash_attention_2"
    torch_dtype = torch.bfloat16
else:
    attn_implementation = "eager"
    torch_dtype = torch.float16


# BitsAndBytesConfig 객체활용 양자화 설정
quant_config = BitsAndBytesConfig(
    # 모델을 4비트 양자화하여 로드할지 여부 결정
    load_in_4bit=True,
    # 양자화 방법 (nf4: Non-Uniform Quantization, "nf4","fp16 등))
    bnb_4bit_quant_type="nf4",
    # (4비트 양자화 시 사용할 데이터 타입, "torch.float16, bfloat16, float32 등)
    bnb_4bit_compute_dtype=torch_dtype,
    # 이중 양자화 사용여부 (이중 양자화는 양자화 과정에서 정밀도 높이기 위해 활용, 대신 더 연산은 복잡)
    bnb_4bit_use_double_quant=False
)

# %% [markdown]
# ## 4. 베이스모델 불러오기

# %%
model = AutoModelForCausalLM.from_pretrained(
    # 불러올 모델 정의
    base_model,
    # 모델 양자화 설정값
    quantization_config=quant_config,
    # 모델의 레이어를 할당할 장치 ("":0 -> 전체 모델을 GPU 0에 할당, "auto"는 알아서, "{"layer_0":0, ... 형태로 레이어별 할당 가능)
    device_map="auto",
)

# 학습 시 캐시 사용 중지 (추론 시엔 켜야 함)
# 학습에 불필요한 캐시·병렬 프리트레인 설정을 꺼서 안정적으로 학습하겠다
# 캐시는 추론용이라, 학습 중엔 메모리만 잡아먹고 오히려 문제
model.config.use_cache = False
# Tensor Parallelism 분할을 끈 상태
#일부 LLaMA 계열에서 값이 1이 아니면 loss 깨짐/느려짐 이슈가 있어, 파인튜닝 시 보통 1로 고정
model.config.pretraining_tp = 1
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## 5. LoRA 및 Trainer 설정

# %%
# LoRA 설정 (어댑터 학습 파트)
peft_params = LoraConfig(    
    # LoRA 랭크(rank). 값이 클수록 "학습 가능한 파라미터"가 늘어서 성능 잠재력은 올라가지만
    # VRAM/학습시간도 조금 증가. (보통 8, 16, 32 자주 사용)
    r=16,

    # LoRA 스케일링 계수. 대체로 r과 비슷하거나 2배 정도로 두는 경우가 많음.
    # 너무 크면 불안정, 너무 작으면 학습이 약해질 수 있음.
    lora_alpha=32,

    # LoRA 레이어에 dropout. 과적합 방지용(데이터가 적을수록 유리).
    # 0.0 ~ 0.1 사이에서 많이 씀.
    lora_dropout=0.05,

    # LoRA는 보통 bias는 학습하지 않음(메모리/일관성 측면에서 깔끔).
    # "all" 같은 옵션도 있지만 대개 none으로 충분.
    bias="none",

    # 원인-결과(next token prediction) 방식의 언어모델 학습(SFT)임을 의미.
    task_type="CAUSAL_LM",

    # "어떤 레이어에 LoRA를 꽂을지" 지정.
    # Transformer의 attention/FFN 핵심 projection들에만 어댑터를 붙여서
    # 전체 모델을 다 학습하지 않고도 성능을 올리는 방식.
    target_modules=["q_proj","k_proj","v_proj","o_proj","gate_proj","up_proj","down_proj"],
)

# %%
# SFTTrainer 학습 설정
sft_args = SFTConfig(
    output_dir="./results",

    # (A) 학습량 / 시간 제어
    # 학습 데이터 전체를 몇 번(epoch) 반복할지
    # 예: 데이터가 약 10,000개라면 1~3 epoch부터 시작 추천
    num_train_epochs=2,
    # GPU 1장(L4 24GB) 기준, 한 번에 올릴 샘플 수
    # OOM 발생 시 가장 먼저 줄일 값
    per_device_train_batch_size=1,

    # 평가 시 배치 크기 (eval도 VRAM 사용)
    per_device_eval_batch_size=1,

    # gradient 누적 스텝 수
    # 유효 배치 크기 = batch_size × gradient_accumulation_steps
    # 예: 1 × 4 = 4
    gradient_accumulation_steps=4,

    # (B) 입력 길이 / 속도 / 메모
    # 최대 토큰 길이
    # 512 → 256으로 줄이면 속도·VRAM 크게 절약됨
    max_length=256,

    # 짧은 샘플들을 하나의 시퀀스로 묶어 학습 효율 증가
    packing=True,

    # 길이가 비슷한 샘플끼리 묶어 패딩 최소화
    group_by_length=True,

    # 학습에 사용할 텍스트 컬럼명
    # train_ds.map()에서 생성한 "text" 컬럼
    dataset_text_field="text",

    # (C) 최적화 하이퍼파라미터
    # LoRA SFT에서 자주 쓰이는 학습률
    learning_rate=2e-4,

    # 가중치 감쇠 (과적합 완화)
    weight_decay=0.001,

    # gradient clipping (폭주 방지)
    max_grad_norm=0.3,

    # 워밍업 비율 (초반 학습 안정화)
    warmup_ratio=0.03,

    # 워밍업 이후 LR 고정
    lr_scheduler_type="constant",

    # (D) 로그 / 평가 / 저장
    # 몇 step마다 로그 출력
    logging_steps=1000,

    # TensorBoard 로깅
    report_to="tensorboard",

    # 평가 비활성화 (속도 우선)
    eval_strategy="no",
    eval_steps=1000,

    # (ref_added) Evaluation 설정 추가
    # eval_strategy="steps",      # step 단위 평가
    # eval_steps=1000,            # 1000 step마다 평가

    # # best model 자동 로드
    # load_best_model_at_end=True,
    # metric_for_best_model="loss",
    # greater_is_better=False,
    
    # 체크포인트 저장 주기
    save_strategy="steps",
    save_steps=1000,

    # 최대 체크포인트 개수 제한
    save_total_limit=3,

    # (E) 혼합정밀도 / 재현성
    # GPU 타입에 따라 fp16 / bf16 사용
    fp16=(torch_dtype == torch.float16),
    bf16=(torch_dtype == torch.bfloat16),

    # 시드 고정
    seed=SEED,
)

# %% [markdown]
# # 모델 훈련

# %%
trainer = SFTTrainer(
    # 학습할 모델
    model=model,
    # 모델 학습에 사용할 데이터셋
    train_dataset=train_ds,
    eval_dataset=None,        # <- 평가를 쓰면 넣고, 안 쓰면 None 가능 대신 상단 eval_strategy="no"
    # Peft (파라미터 효율적 미세 조정) 설정 정의
    peft_config=peft_params,
    #모델에 함께 사용할 토크나이저
    processing_class=tokenizer,  # TRL 최신 방식: tokenizer 전달
    # 훈련 파라미터 설정
    args=sft_args,
)
# Out:
# Converting train dataset to ChatML:   0%|          | 0/15360 [00:00<?, ? examples/s]
# Applying chat template to train dataset:   0%|          | 0/15360 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/15360 [00:00<?, ? examples/s]
# Packing train dataset:   0%|          | 0/15360 [00:00<?, ? examples/s]
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.

# %%
trainer.train()
# Out:
# It is strongly recommended to train Gemma3 models with the `eager` attention implementation instead of `sdpa`. Use `eager` with `AutoModelForCausalLM.from_pretrained('<path-to-checkpoint>', attn_implementation='eager')`.
#     <div>
#
#       <progress value='92' max='5146' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  92/5146 02:05 < 1:57:18, 0.72 it/s, Epoch 0.04/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./results/runs

# %% [markdown]
# ## 7. 어댑터 저장 (학습된 LoRA Adapter만 저장하여 용량을 줄임)

# %%
now_str = datetime.now().strftime("%Y_%m_%d_%H")
preFix = base_model.split("/")[1]
savePath = f"/content/gdrive/MyDrive/Colab Notebooks/models/{preFix}_{now_str}"

if inColab == True:
    savePath = f"/content/gdrive/MyDrive/Colab Notebooks/models/{preFix}_{now_str}"
    trainer.save_model(savePath)
else:
    savePath = f"./models/{preFix}_{now_str}"
    trainer.save_model(savePath)

# 어댑터 및 토크나이저 저장
trainer.model.save_pretrained(savePath)
tokenizer.save_pretrained(savePath)
# trainer.save_model(savePath)
print("저장 완료:", savePath)
# Out:
# 저장 완료: ./models/elysium_general_2026_02_07_13

# %% [markdown]
# ## 참고. 추론 테스트 (현재 세션)

# %%
train_ds[10]
# Out:
# {'text': '<bos><start_of_turn>user\nHydroxychloroquine 사용 시 발생할 수 있는 대표적인 부작용은 무엇인가?  \n1) 혈당 감소  \n2) 면역 억제  \n3) QT 간격 연장  \n4) 혈압 상승\n\n[입력]\n내과<end_of_turn>\n<start_of_turn>model\n3) QT 간격 연장<end_of_turn>\n'}

# %%
def infer_gemma(question, max_new_tokens=256, temperature=0.7, top_p=0.9):
    model.eval()
    messages = [{"role": "user", "content": question}]

    try:
        prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    except Exception:
        prompt = (
            "<start_of_turn>user\n"
            f"{question}\n"
            "<end_of_turn>\n"
            "<start_of_turn>model\n"
        )

    inputs = tokenizer(prompt, return_tensors="pt")
    inputs = {k: v.to(model.device) for k, v in inputs.items()}

    model_dtype = next(model.parameters()).dtype  # torch.float16 or torch.bfloat16 or torch.float32

    # (중요) generate를 autocast로 감싸서 내부 연산 dtype을 통일
    # bf16 가능하면 bf16, 아니면 fp16
    amp_dtype = model_dtype if model_dtype in (torch.float16, torch.bfloat16) else torch.float16

    with torch.no_grad(), torch.autocast(device_type="cuda", dtype=amp_dtype):
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=True,
            temperature=temperature,
            top_p=top_p,
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.eos_token_id,
            use_cache=False,  # (중요) cache 끄면 dtype 꼬임이 줄어드는 경우가 많음
        )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
print("Q1:", infer_gemma("HFNC(고유량 비강 캐뉼라)가 환자의 호흡 부담을 감소시키는 주요 기전은 무엇인가?  \n1) 호흡수를 증가시킨다.  \n2) 해부학적 사강(Anatomical dead space)을 감소시킨다.  \n3) 산소 농도를 낮춘다.  \n4) 가온가습 기능 없이 사용한다.  \n5) 낮은 유량으로 산소를 공급한다."))
# print("Q2:", infer_gemma("스마트금융과는 어디에 위치하나요?"))
# Out:
# You have set `use_cache` to `False`, but cache_implementation is set to hybrid. cache_implementation will have no effect.
# Q1: user
# HFNC(고유량 비강 캐뉼라)가 환자의 호흡 부담을 감소시키는 주요 기전은 무엇인가?
# 1) 호흡수를 증가시킨다.
# 2) 해부학적 사강(Anatomical dead space)을 감소시킨다.
# 3) 산소 농도를 낮춘다.
# 4) 가온가습 기능 없이 사용한다.
# 5) 낮은 유량으로 산소를 공급한다.
# model
# 2) 해부학적 사강(Anatomical dead space)을 감소시킨다.

# %%
infer_gemma("45세 여성이 지속적인 속쓰림과 가슴 쓰림을 주소로 내원하였습니다. 환자는 비만이며, 최근 체중 증가와 함께 증상이 악화되었다고 합니다. 환자는 또한 목소리가 쉬고, 자주 기침을 한다고 호소하고 있습니다. 위식도역류질환(GERD)로 진단받았으며, 비약물적 치료 방법을 시작하기로 하였습니다. 다음 중 이 환자에게 가장 적절한 비약물적 치료 방법은 무엇인가요?  \n1) 식사 후 바로 눕기  \n2) 저녁식사 후 최소 3시간이 지난 후에 취침하기  \n3) 침대 머리 부분을 15-30도 올리기  \n4) 매 식사마다 소량씩 자주 섭취하기  \n5) 음주와 흡연을 중단하기")
# print("Q2:", infer_gemma("스마트금융과는 어디에 위치하나요?"))
# Out:
# 'user\n45세 여성이 지속적인 속쓰림과 가슴 쓰림을 주소로 내원하였습니다. 환자는 비만이며, 최근 체중 증가와 함께 증상이 악화되었다고 합니다. 환자는 또한 목소리가 쉬고, 자주 기침을 한다고 호소하고 있습니다. 위식도역류질환(GERD)로 진단받았으며, 비약물적 치료 방법을 시작하기로 하였습니다. 다음 중 이 환자에게 가장 적절한 비약물적 치료 방법은 무엇인가요?  \n1) 식사 후 바로 눕기  \n2) 저녁식사 후 최소 3시간이 지난 후에 취침하기  \n3) 침대 머리 부분을 15-30도 올리기  \n4) 매 식사마다 소량씩 자주 섭취하기  \n5) 음주와 흡연을 중단하기\nmodel\n3) 침대 머리 부분을 15-30도 올리기\n'

# %%
answer
# Out:
# 'user\n심장 수술을 받는 성인 환자에서 수술 전 스타틴 요법의 효과에 대한 최신 연구 결과에 근거한 올바른 결론은 무엇인가?  \n1) 스타틴 요법은 수술 후 단기 사망률을 유의미하게 감소시킨다.  \n2) 스타틴 요법은 수술 후 주요 유해 심혈관 사건 발생률을 유의미하게 증가시킨다.  \n3) 스타틴 요법은 수술 후 심근경색 발생률을 유의미하게 감소시킨다.  \n4) 스타틴 요법은 수술 후 사망률, 심근경색, 입원 기간 등에 유의미한 차이가 없다.  \n5) 스타틴 요법은 수술 후 신부전 발생률을 유의미하게 감소시킨다.\nmodel\n3) 스타틴 요법은 수술 후 심근경색 발생률을 유의미하게 감소시킨다.\nuser\n고혈압 환자에서 혈압 강하를 위한 치료 방법으로 사용되는 약물 중, 혈압을 낮추는 데 가장 효과적이고, 다른 혈압 강하 효과도 일부 가지는 약물은 무엇인가?  \n1) 아목시세린  \n2) 톨라제르신  \n3) 메토프롤롤  \n4) 카르베디롤  \n5) 렘베르사이드\nmodel\n4) 카르베디롤\nuser\n45세 남자가 최근 몇 달 동안 잦은 야간 통증으로 고통받고 있으며, 통증은 주로 다리에서 시작하여 목과 어깨로 이어지는 느낌이다. 환자는 최근 심장 질환이 없다고 보고되었으며, 과거 병력상 특별한 것은 없다. 신체검사에서 목과 어깨 근육의 압통과 뻣뻣감이 관찰되었고, 심전도 검사에서는 특이 소견이 관찰되지 않았다. 이 환자에게 가장 가능성이 높은'

# %%
train_ds['text'][0]
# Out:
# '<bos><start_of_turn>user\n52세 남자가 복부 팽만감과 우상복부 통증으로 병원을 방문하였다. 과거력 상 진단된 질환은 없으나 최근 체중 감소와 피로감을 호소하였다. 신체검사에서 복수와 간비대가 관찰되었으며, 피부는 약간의 황달을 띠고 있었다. 복부 초음파 검사에서는 간의 중심부에 비해 주변부의 밀도가 낮아 보이고, 간문맥의 비정상적인 혈류가 관찰되었다. 간 조직검사 결과 중심엽에서의 간세포 괴사와 높은 정도의 정맥 울혈이 확인되었다. 이 환자의 가장 가능성이 높은 진단은 무엇인가?  \n1) 알코올성 간경변  \n2) 비알코올성 지방간염  \n3) 자가면역 간염  \n4) Budd-Chiari 증후군  \n5) 원발성 경화성 담관염\n\n[입력]\n내과<end_of_turn>\n<start_of_turn>model\n4) Budd-Chiari 증후군<end_of_turn>\n'
